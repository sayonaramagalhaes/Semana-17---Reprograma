# %% [markdown]
# <a href="https://colab.research.google.com/github/sayonaramagalhaes/Semana-17---Reprograma/blob/main/ListadeEspera.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df=pd.read_csv('/content/Relatório de lista de espera por um transplante de órgão ou córnea (Rio Grande do Norte) - Série histórica 2008-2023 - Table 1.csv')

# %%
df.head(10)
# Out:
#     Ano  Coração  Fígado  Pulmão  Rim  Pâncreas  Pâncreas Rim  Intestino  \
# 0  2013        0       5       0   61         0             0          0
# 1  2014        0       0       0  153         0             0          0
# 2  2015        0       0       0  180         0             0          0
# 3  2016        0       0       0  162         0             0          0
# 4  2017        0       0       0  165         0             0          0
# 5  2018        0       0       0  299         0             0          0
# 6  2019        0       0       0  306         0             0          0
# 7  2020        0       0       0  278         0             0          0
# 8  2021        1       0       0  301         0             0          0
# 9  2022        3       0       0  307         0             0          0
#
#    Multivisceral  SubTotal  Córnea  Total
# 0              0        66      73    139
# 1              0       153      55    208
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11 entries, 0 to 10
# Data columns (total 12 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Ano            11 non-null     int64
#  1   Coração        11 non-null     int64
#  2   Fígado         11 non-null     int64
#  3   Pulmão         11 non-null     int64
#  4   Rim            11 non-null     int64
#  5   Pâncreas       11 non-null     int64
#  6   Pâncreas Rim   11 non-null     int64
#  7   Intestino      11 non-null     int64
#  8   Multivisceral  11 non-null     int64
#  9   SubTotal       11 non-null     int64
#  10  Córnea         11 non-null     int64
#  11  Total          11 non-null     int64
# dtypes: int64(12)
# memory usage: 1.2 KB

# %%
df.describe()
# Out:
#                Ano    Coração     Fígado  Pulmão         Rim  Pâncreas  \
# count    11.000000  11.000000  11.000000    11.0   11.000000      11.0
# mean   2018.000000   0.454545   0.454545     0.0  231.090909       0.0
# std       3.316625   0.934199   1.507557     0.0   89.239514       0.0
# min    2013.000000   0.000000   0.000000     0.0   61.000000       0.0
# 25%    2015.500000   0.000000   0.000000     0.0  163.500000       0.0
# 50%    2018.000000   0.000000   0.000000     0.0  278.000000       0.0
# 75%    2020.500000   0.500000   0.000000     0.0  303.500000       0.0
# max    2023.000000   3.000000   5.000000     0.0  330.000000       0.0
#
#        Pâncreas Rim  Intestino  Multivisceral    SubTotal      Córnea  \
# count          11.0       11.0           11.0   11.000000   11.000000
# mean            0.0        0.0            0.0  232.000000  272.909091
# std             0.0        0.0            0.0   88.744577  195.478109
# ...

# %%
#salvar dataset
df.to_csv('dataset.csv', index=False)

# %%
#fazer dowload
from google.colab import files
files.download('dataset.csv')

# %%
df=pd.read_csv('/content/dataset.csv')
df.head(10)

# %%
#grafico ano
